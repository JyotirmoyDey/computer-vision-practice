# %%
import numpy as np
import matplotlib.image as mping
import matplotlib.pyplot as plt
import cv2

# %matplotlib qt
# %matplotlib inline

# %%
image = mping.imread('red_sports_car_200689.jpg')
plt.imshow(image)
image.shape
# Out:
# (3333, 5000, 3)

# %%
gray_scale_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray_scale_image, cmap='gray')

# %%
# print specific grayscale pixel values
x = 1000
y =200
print(gray_scale_image[x,y])
# Out:
# 107
